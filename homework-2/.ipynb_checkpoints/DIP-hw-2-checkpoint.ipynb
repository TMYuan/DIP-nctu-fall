# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

plt.rcParams['figure.figsize'] = (10.0, 8.0)

# %%
image = Image.open('./data/input1.bmp')

print('Format: {}, Size: {}, Mode: {}'.format(image.format, image.size, image.mode))
plt.imshow(image)
# Out:
# Format: BMP, Size: (1200, 800), Mode: RGB

# %%
img_data = np.asarray(image)
img_data.shape
# Out:
# (800, 1200, 3)

# %%
r, g, b = image.split()

fig, axs = plt.subplots(2,2)
axs[0, 0].imshow(r, cmap='gray')
axs[0, 0].set_title('RED')
axs[0, 1].imshow(g, cmap='gray')
axs[0, 1].set_title('GREEN')
axs[1, 0].imshow(b, cmap='gray')
axs[1, 0].set_title('BLUE')
plt.show()

# %%
r = np.asarray(r)
g = np.asarray(g)
b = np.asarray(b)
# plt.hist(r.ravel(), fc='k', ec='k')

fig, axs = plt.subplots(3)
axs[0].hist(r.ravel(), fc='k', ec='k', bins=255)
axs[0].set_title('RED')
axs[1].hist(g.ravel(), fc='k', ec='k', bins=255)
axs[1].set_title('GREEN')
axs[2].hist(b.ravel(), fc='k', ec='k', bins=255)
axs[2].set_title('BLUE')
plt.show()

# %%
new_image = np.asarray(image).astype('float32')
new_image
# Out:
# array([[[ 201.,  180.,  126.],
#         [ 198.,  174.,  117.],
#         [ 198.,  175.,  116.],
#         ...,
#         [ 143.,  114.,   51.],
#         [ 150.,  113.,   51.],
#         [ 157.,  122.,   63.]],
#
#        [[ 195.,  175.,  109.],
#         [ 191.,  170.,  102.],
#         [ 193.,  170.,  102.],
#         ...,
#         [ 145.,  116.,   42.],
#         [ 148.,  114.,   41.],
#         [ 156.,  123.,   52.]],
#
#        [[ 195.,  178.,  113.],
#         [ 192.,  171.,  104.],
#         [ 193.,  172.,  105.],
#         ...,
#         [ 159.,  128.,   53.],
#         [ 161.,  131.,   53.],
#         [ 169.,  140.,   67.]],
#
#        ...,
#        [[ 242.,  183.,  106.],
#         [ 239.,  178.,   93.],
#         [ 240.,  177.,   92.],
#         ...,
#         [ 242.,  172.,   88.],
#         [ 241.,  172.,   92.],
#         [ 241.,  178.,  106.]],
#
#        [[ 241.,  183.,  106.],
#         [ 239.,  182.,   99.],
#         [ 239.,  179.,   98.],
#         ...,
#         [ 242.,  173.,   89.],
#         [ 242.,  174.,   91.],
#         [ 242.,  177.,  100.]],
#
#        [[ 241.,  187.,  118.],
#         [ 239.,  185.,  110.],
#         [ 241.,  184.,  110.],
#         ...,
#         [ 243.,  183.,  106.],
#         [ 244.,  183.,  106.],
#         [ 244.,  186.,  116.]]], dtype=float32)

# %%
# new_image /= 255.0
# new_image[new_image <= 0.04045] /= 12.92
# new_image[new_image > 0.04045] = np.power((new_image[new_image > 0.04045]+0.055)/(1+0.055), 2.4)

# new_image.shape

# %%
# new_image = np.transpose(new_image, (2, 0, 1)).reshape(3, -1)
# to_xyz = np.array([[0.4124, 0.3576, 0.1805], [0.2126, 0.7152, 0.07222], [0.0193, 0.11922, 0.9505]], np.float32)

# %%
# new_image = np.matmul(to_xyz, new_image)
# new_image.shape

# %%
# new_image = np.transpose(new_image.reshape(3, 800, 1200), (1, 2, 0))
# new_image.shape

# %%
white_pixel = new_image[550][180]
# new_image = np.transpose(new_image, (2, 0, 1)).reshape(3, -1)
# white_balance = np.array([
#     [243.0/white_pixel[0], 0, 0],
#     [0, 243.0/white_pixel[1], 0],
#     [0, 0, 242.0/white_pixel[2]]
# ], np.float32)

# %%
# new_image = np.matmul(white_balance, new_image)
# new_image = np.transpose(new_image.reshape(3, 800, 1200), (1, 2, 0))
# new_image.shape

# %%
# new_image[new_image > 255] = 255
# new_image[new_image < 0] = 0
# new_image = new_image.astype(np.uint8)
# plt.imshow(new_image)

# %%
black_pixel = new_image[550][650]
new_image = np.transpose(new_image, (2, 0, 1)).reshape(3, -1)
black_balance = np.array([
    [(243.0-52.0)/(white_pixel[0]-black_pixel[0]), 0, 0],
    [0, (243.0-52.0)/(white_pixel[1]-black_pixel[1]), 0],
    [0, 0, (242.0-52.0)/(white_pixel[2]-black_pixel[2])]
], np.float32)

black_pixel = black_pixel[:, np.newaxis]
black_pixel
# Out:
# array([[ 23.],
#        [ 23.],
#        [  6.]], dtype=float32)

# %%
new_image = np.matmul(black_balance, (new_image-black_pixel))
new_image += 52
new_image = np.transpose(new_image.reshape(3, 800, 1200), (1, 2, 0))
new_image
# Out:
# array([[[ 213.89523315,  213.22042847,  211.44056702],
#         [ 211.16665649,  207.05914307,  199.48251343],
#         [ 211.16665649,  208.08601379,  198.15385437],
#         ...,
#         [ 161.14285278,  145.44622803,  111.79020691],
#         [ 167.50952148,  144.41934204,  111.79020691],
#         [ 173.87619019,  153.6612854 ,  127.73426819]],
#
#        [[ 208.43809509,  208.08601379,  188.85314941],
#         [ 204.80000305,  202.95161438,  179.55244446],
#         [ 206.61904907,  202.95161438,  179.55244446],
#         ...,
#         [ 162.9618988 ,  147.5       ,   99.83216858],
#         [ 165.69047546,  145.44622803,   98.50349426],
#         [ 172.9666748 ,  154.68817139,  113.11888123]],
#
#        [[ 208.43809509,  211.16665649,  194.16783142],
#         [ 205.70951843,  203.97848511,  182.20979309],
#         [ 206.61904907,  205.00537109,  183.53846741],
#         ...,
#         [ 175.69523621,  159.8225708 ,  114.44755554],
#         [ 177.51428223,  162.90322876,  114.44755554],
#         [ 184.79046631,  172.14515686,  133.0489502 ]],
#
#        ...,
#        [[ 251.18571472,  216.30107117,  184.86712646],
#         [ 248.45713806,  211.16665649,  167.59440613],
#         [ 249.3666687 ,  210.13978577,  166.26573181],
#         ...,
#         [ 251.18571472,  205.00537109,  160.9510498 ],
#         [ 250.27618408,  205.00537109,  166.26573181],
#         [ 250.27618408,  211.16665649,  184.86712646]],
#
#        [[ 250.27618408,  216.30107117,  184.86712646],
#         [ 248.45713806,  215.27418518,  175.56643677],
#         [ 248.45713806,  212.19354248,  174.23776245],
#         ...,
#         [ 251.18571472,  206.03225708,  162.27972412],
#         [ 251.18571472,  207.05914307,  164.93707275],
#         [ 251.18571472,  210.13978577,  176.89511108]],
#
#        [[ 250.27618408,  220.40859985,  200.81118774],
#         [ 248.45713806,  218.35482788,  190.18182373],
#         [ 250.27618408,  217.32795715,  190.18182373],
#         ...,
#         [ 252.0952301 ,  216.30107117,  184.86712646],
#         [ 253.00476074,  216.30107117,  184.86712646],
#         [ 253.00476074,  219.38171387,  198.15385437]]], dtype=float32)

# %%
new_image[new_image > 255] = 255
new_image[new_image < 0] = 0
new_image = new_image.astype(np.uint8)
plt.imshow(new_image)
